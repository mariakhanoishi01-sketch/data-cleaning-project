# %% [markdown]
# <a href="https://colab.research.google.com/github/mariakhanoishi01-sketch/data-cleaning-project/blob/main/02_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import amr_eda as eda

eda.run_eda(
    Path("metadata_cleaned.csv")
)
# Out:
# ...
# RAW MIC — DESCRIPTIVE STATISTICS
# ...
#        Azithromycin  Ciprofloxacin  Ceftriaxone   Cefixime  Tetracycline  Penicillin
# count     3478.0000      3088.0000    3434.0000  3401.0000     1472.0000   1465.0000
# mean        17.1188         7.4288       0.0300     0.0644        7.3861      3.0441
# std         90.8645        11.2668       0.0804     0.1992       22.1008     15.4480
# min          0.0040         0.0010       0.0002     0.0010        0.0080      0.0020
# 25%          0.1250         0.0040       0.0040     0.0150        0.5000      0.2500
# 50%          0.3800         0.0940       0.0150     0.0160        2.0000      0.5000
# 75%          1.0000        16.0000       0.0320     0.0600        4.0000      2.0000
# max       1024.0000        64.0000       2.0000     8.0000      256.0000    512.0000
#
# ...
# LOG₂ MIC — DESCRIPTIVE STATISTICS
# ...
#        Azithromycin  Ciprofloxacin  Ceftriaxone   Cefixime  Tetracycline  Penicillin
# ...

# %%
# !pip install pandas numpy matplotlib seaborn scipy

# %%
import os

os.makedirs("visuals", exist_ok=True)

print("Visuals folder created.")
# Out:
# Visuals folder created.

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'data_quality_report.py',
#  'visuals',
#  'amr_eda.py',
#  'metadata_cleaned.csv',
#  '__pycache__',
#  'sample_data']

# %%
import importlib.util

spec = importlib.util.spec_from_file_location(
    "amr_eda",
    "/content/amr_eda.py"
)

eda = importlib.util.module_from_spec(spec)

spec.loader.exec_module(eda)

print("EDA module loaded successfully.")
# Out:
# EDA module loaded successfully.

# %%
from pathlib import Path

eda.run_eda(
    Path("metadata_cleaned.csv")
)
# Out:
# ...
# RAW MIC — DESCRIPTIVE STATISTICS
# ...
#        Azithromycin  Ciprofloxacin  Ceftriaxone   Cefixime  Tetracycline  Penicillin
# count     3478.0000      3088.0000    3434.0000  3401.0000     1472.0000   1465.0000
# mean        17.1188         7.4288       0.0300     0.0644        7.3861      3.0441
# std         90.8645        11.2668       0.0804     0.1992       22.1008     15.4480
# min          0.0040         0.0010       0.0002     0.0010        0.0080      0.0020
# 25%          0.1250         0.0040       0.0040     0.0150        0.5000      0.2500
# 50%          0.3800         0.0940       0.0150     0.0160        2.0000      0.5000
# 75%          1.0000        16.0000       0.0320     0.0600        4.0000      2.0000
# max       1024.0000        64.0000       2.0000     8.0000      256.0000    512.0000
#
# ...
# LOG₂ MIC — DESCRIPTIVE STATISTICS
# ...
#        Azithromycin  Ciprofloxacin  Ceftriaxone   Cefixime  Tetracycline  Penicillin
# ...

# %%
import os

visuals = os.listdir("visuals")

print(f"Total files generated: {len(visuals)}")

for file in visuals:
    print(file)
# Out:
# Total files generated: 21
# 03a_samples_by_continent.png
# 04b_sr_correlation_heatmap.png
# 04c_pairplot_mic.png
# 02b_raw_mic_histograms.png
# 03b_top15_countries.png
# 05a_overall_resistance_rates.png
# 03d_beta_lactamase_status.png
# 06d_azm_vs_cip_scatter.png
# 05c_resistance_trend_over_time.png
# 03e_continent_year_heatmap.png
# 01_descriptive_statistics.png
# 02a_log2_mic_histograms.png
# 04a_correlation_heatmap.png
# 03c_isolates_by_year.png
# 05b_resistance_by_continent.png
# 06b_mic_susceptible_vs_resistant.png
# 05d_mdr_continent_heatmap.png
# 06a_log2_mic_boxplots.png
# 06c_antibiotic_effectiveness_ranking.png
# 02c_kde_overlay.png
# 00_dashboard_summary.png

# %%
import os

sorted(os.listdir("visuals"))
# Out:
# ['00_dashboard_summary.png',
#  '01_descriptive_statistics.png',
#  '02a_log2_mic_histograms.png',
#  '02b_raw_mic_histograms.png',
#  '02c_kde_overlay.png',
#  '03a_samples_by_continent.png',
#  '03b_top15_countries.png',
#  '03c_isolates_by_year.png',
#  '03d_beta_lactamase_status.png',
#  '03e_continent_year_heatmap.png',
#  '04a_correlation_heatmap.png',
#  '04b_sr_correlation_heatmap.png',
#  '04c_pairplot_mic.png',
#  '05a_overall_resistance_rates.png',
#  '05b_resistance_by_continent.png',
#  '05c_resistance_trend_over_time.png',
#  '05d_mdr_continent_heatmap.png',
#  '06a_log2_mic_boxplots.png',
#  '06b_mic_susceptible_vs_resistant.png',
#  '06c_antibiotic_effectiveness_ranking.png',
#  '06d_azm_vs_cip_scatter.png']

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(
    "visuals/00_dashboard_summary.png"
)

plt.figure(figsize=(15,8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(
    "visuals/04a_correlation_heatmap.png"
)

plt.figure(figsize=(12,10))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# !zip -r eda_results.zip visuals
# Out:
#   adding: visuals/ (stored 0%)
#   adding: visuals/03a_samples_by_continent.png (deflated 20%)
#   adding: visuals/04b_sr_correlation_heatmap.png (deflated 13%)
#   adding: visuals/04c_pairplot_mic.png (deflated 9%)
#   adding: visuals/02b_raw_mic_histograms.png (deflated 22%)
#   adding: visuals/03b_top15_countries.png (deflated 21%)
#   adding: visuals/05a_overall_resistance_rates.png (deflated 16%)
#   adding: visuals/03d_beta_lactamase_status.png (deflated 12%)
#   adding: visuals/06d_azm_vs_cip_scatter.png (deflated 11%)
#   adding: visuals/05c_resistance_trend_over_time.png (deflated 6%)
#   adding: visuals/03e_continent_year_heatmap.png (deflated 16%)
#   adding: visuals/01_descriptive_statistics.png (deflated 14%)
#   adding: visuals/02a_log2_mic_histograms.png (deflated 8%)
#   adding: visuals/04a_correlation_heatmap.png (deflated 12%)
#   adding: visuals/03c_isolates_by_year.png (deflated 15%)
#   adding: visuals/05b_resistance_by_continent.png (deflated 24%)
# ...

# %%
from google.colab import files

files.download("eda_results.zip")
